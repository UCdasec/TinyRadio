# %%
roc_data_path='/home/mabon/TinyRadio/Modulation/experiments/ResNet/2021_27/BASELINE/server/BASELINE/inference/roc_data.npz'
loaded_data = np.load(roc_data_path,allow_pickle=True)
# Create a dictionary to hold the loaded data
loaded_dict = {
    'fpr': loaded_data['fpr'].tolist(),
    'tpr': loaded_data['tpr'].tolist(),
    'thresholds': loaded_data['thresholds'].tolist(),
    'roc_auc': loaded_data['roc_auc'].tolist()
}

# %%
import os
# Plot ROC curve
plt.figure(figsize=(10, 10))
for i in range(num_classes):
    plt.plot(loaded_dict["fpr"][i], loaded_dict["tpr"][i], lw=2, label=f'Class {mods[i]} (AUC = {loaded_dict["roc_auc"][i]:0.2f})')

plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.show()
